# %% [markdown]
# # import libraries and data

# %%
import numpy as np
import pandas as pd

df=pd.read_csv('D:\\Datasets\\Housingdata.csv')
df
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0    313000         3       1.50         1340      7912     1.5           0
# 1   2384000         5       2.50         3650      9050     2.0           0
# 2    342000         3       2.00         1930     11947     1.0           0
# 3    420000         3       2.25         2000      8030     1.0           0
# 4    550000         4       2.50         1940     10500     1.0           0
# ..      ...       ...        ...          ...       ...     ...         ...
# 64   625000         4       2.75         2920      6605     2.0           0
# 65   553000         2       1.00          900      5000     1.0           0
# 66   379880         3       2.50         1650     14054     1.0           0
# 67   310000         3       1.00         1010      9945     1.0           0
# 68   775000         2       2.50         2680      7392     1.0           0
#
# ...

# %%
x=df.iloc[:,1:6]
x
y=df.iloc[:,0:1]
print(x,y)
# Out:
#     bedrooms  bathrooms  sqft_living  sqft_lot  floors
# 0          3       1.50         1340      7912     1.5
# 1          5       2.50         3650      9050     2.0
# 2          3       2.00         1930     11947     1.0
# 3          3       2.25         2000      8030     1.0
# 4          4       2.50         1940     10500     1.0
# ..       ...        ...          ...       ...     ...
# 64         4       2.75         2920      6605     2.0
# 65         2       1.00          900      5000     1.0
# 66         3       2.50         1650     14054     1.0
# 67         3       1.00         1010      9945     1.0
# 68         2       2.50         2680      7392     1.0
#
# [69 rows x 5 columns]       price
# 0    313000
# 1   2384000
# 2    342000
# 3    420000
# 4    550000
# ..      ...
# 64   625000
# 65   553000
# 66   379880
# 67   310000
# 68   775000
#
# [69 rows x 1 columns]

# %% [markdown]
# # Split data and fit model

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor


x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.80,test_size=0.20,random_state=2018)

knn=KNeighborsRegressor(n_neighbors=5)

knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
y_pred
# Out:
# array([[631190.],
#        [333000.],
#        [555500.],
#        [499900.],
#        [481890.],
#        [564300.],
#        [398076.],
#        [388000.],
#        [490600.],
#        [499900.],
#        [931800.],
#        [549700.],
#        [549700.],
#        [440330.]])

# %% [markdown]
# # Mean Sq Error

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
l=len(df)
t=[]
for i in range(1,l-2):
    knn=KNeighborsRegressor(n_neighbors=i)
    knn.fit(x_train,y_train)
   # y_pred=knn.predict(x_test)
    MSE=np.sqrt(mean_squared_error(y_test,y_pred))
    t.append(float(MSE))
    print("MSE when k is "+str(i)+"=", MSE)
# Out:
# MSE when k is 1= 175314.5634028812
# MSE when k is 2= 175314.5634028812
# MSE when k is 3= 175314.5634028812
# MSE when k is 4= 175314.5634028812
# MSE when k is 5= 175314.5634028812
# MSE when k is 6= 175314.5634028812
# MSE when k is 7= 175314.5634028812
# MSE when k is 8= 175314.5634028812
# MSE when k is 9= 175314.5634028812
# MSE when k is 10= 175314.5634028812
# MSE when k is 11= 175314.5634028812
# MSE when k is 12= 175314.5634028812
# MSE when k is 13= 175314.5634028812
# MSE when k is 14= 175314.5634028812
# MSE when k is 15= 175314.5634028812
# MSE when k is 16= 175314.5634028812
# MSE when k is 17= 175314.5634028812
# MSE when k is 18= 175314.5634028812
# MSE when k is 19= 175314.5634028812
# MSE when k is 20= 175314.5634028812
# MSE when k is 21= 175314.5634028812
# MSE when k is 22= 175314.5634028812
# MSE when k is 23= 175314.5634028812
# MSE when k is 24= 175314.5634028812
# MSE when k is 25= 175314.5634028812
# MSE when k is 26= 175314.5634028812
# ...

# %% [markdown]
# # Root Mean Square Error

# %%
from sklearn.metrics import mean_squared_error
import math

for i in range(1,len(df)-2):
    knn=KNeighborsRegressor(n_neighbors=i)
    knn.fit(x_train,y_train)
    y_pred=knn.predict(x_test)
    MSE=np.sqrt(mean_squared_error(y_test,y_pred))

    RMSE=math.sqrt(MSE)
    print("RMSE when k is "+str(i)+"=", RMSE)
# Out:
# RMSE when k is 1= 518.0995682041064
# RMSE when k is 2= 424.14057524377466
# RMSE when k is 3= 394.1403539927637
# RMSE when k is 4= 381.6038625985856
# RMSE when k is 5= 418.7058196429579
# RMSE when k is 6= 440.90549181667666
# RMSE when k is 7= 457.32278960975236
# RMSE when k is 8= 464.29173406851055
# RMSE when k is 9= 476.0537750628765
# RMSE when k is 10= 483.06861577681696
# RMSE when k is 11= 475.9426871154009
# RMSE when k is 12= 478.6168663272256
# RMSE when k is 13= 481.18463993557725
# RMSE when k is 14= 484.4983560684015
# RMSE when k is 15= 485.13012643065423
# RMSE when k is 16= 477.4411175134451
# RMSE when k is 17= 485.9019662752535
# RMSE when k is 18= 502.9904692476255
# RMSE when k is 19= 506.6424343503445
# RMSE when k is 20= 508.0444282578748
# RMSE when k is 21= 509.64755808596254
# RMSE when k is 22= 508.8815128714271
# RMSE when k is 23= 509.0584940809933
# RMSE when k is 24= 505.6654962857477
# RMSE when k is 25= 497.15800798179674
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

df=pd.read_csv("D:\\Datasets\\Salary_data.csv")
df

X=df.iloc[:, 0].values.reshape(-1,1)
Y=df.iloc[:, 1].values.reshape(-1,1)
print(X,Y)

linear_regression=LinearRegression()
linear_regression.fit(X,Y)
y_pred= linear_regression.predict(X)

plt.scatter(x,y)
plt.plot(x,y_pred,color='r')
plt.show()
